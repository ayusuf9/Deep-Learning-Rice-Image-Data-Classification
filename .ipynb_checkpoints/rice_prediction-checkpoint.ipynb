# %% [markdown]
# # Rice Image Dataset Classification
# ### Using MobileNet Transfer Learning
#
# `By Yusuf Musa`
#
# - DATASET: https://www.muratkoklu.com/datasets/
# - Citation: Koklu, M., Cinar, I., & Taspinar, Y. S. (2021).
# - Classification of rice varieties with deep learning methods.
# - Computers and Electronics in Agriculture, 187, 106285.

# %%
import kagglehub
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
import numpy as np
import pathlib
import warnings

warnings.filterwarnings("ignore")

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow version: 2.21.0

# %% [markdown]
# # 1. CONFIGURATION

# %%
DATA_DIR = pathlib.Path("./Rice_Image_Dataset")

if not DATA_DIR.exists():
    print("Dataset not found locally. Downloading from Kaggle...")
    path = kagglehub.dataset_download("muratkokludataset/rice-image-dataset")
    DATA_DIR = pathlib.Path(path) / "Rice_Image_Dataset"
    print(f"Dataset downloaded to: {DATA_DIR}")
else:
    print("Dataset found locally.")
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 30
SAMPLES_PER_CLASS = 1500

CLASS_LABELS = {
    "Arborio": 0,
    "Basmati": 1,
    "Ipsala": 2,
    "Jasmine": 3,
    "Karacadag": 4,
}
NUM_CLASSES = len(CLASS_LABELS)
# Out:
# Dataset not found locally. Downloading from Kaggle...
# Dataset downloaded to: /Users/yusufmusa/.cache/kagglehub/datasets/muratkokludataset/rice-image-dataset/versions/1/Rice_Image_Dataset

# %% [markdown]
# # 2. LOAD AND PREPARE DATA

# %%
X, y = [], []
for label_name, label_id in CLASS_LABELS.items():
    images = list(DATA_DIR.glob(f"{label_name}/*"))[:SAMPLES_PER_CLASS]
    for image_path in images:
        img = cv2.imread(str(image_path))
        if img is None:
            continue
        resized = cv2.resize(img, IMG_SIZE)
        X.append(resized)
        y.append(label_id)

X = np.array(X, dtype=np.float32) / 255.0
y = np.array(y)

# %% [markdown]
# ### Stratified splits with fixed seed for reproducibility

# %%
X_train, X_test_val, y_train, y_test_val = train_test_split(
    X, y, test_size=0.25, random_state=SEED, stratify=y
)
X_test, X_val, y_test, y_val = train_test_split(
    X_test_val, y_test_val, test_size=0.5, random_state=SEED, stratify=y_test_val
)

# %% [markdown]
# # 3. DATA AUGMENTATION

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.1,
)
train_generator = train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE, seed=SEED)

# %% [markdown]
# # 4. VISUALIZE SAMPLES
#
# - The images are stored as numpy arrays of pixel values. Each pixel has 3 channels (Blue, Green, Red from OpenCV).
# - Originally values are 0–255 integers, but the script divides by 255 to normalize them to 0.0–1.0 floats (which is what the model expects).
# - The `cv2.cvtColor` and `* 255` in the display code below is just converting them back to proper format for matplotlib to show correctly.

# %%
fig, axes = plt.subplots(ncols=NUM_CLASSES, figsize=(20, 5))
fig.suptitle("Rice Varieties")
class_names = list(CLASS_LABELS.keys())
for i, name in enumerate(class_names):
    idx = np.where(y == i)[0][0]
    axes[i].set_title(name)
    axes[i].imshow(cv2.cvtColor((X[idx] * 255).astype(np.uint8), cv2.COLOR_BGR2RGB))
    axes[i].axis("off")
plt.tight_layout()
plt.savefig("sample_images.png", dpi=100)
plt.show()

# %% [markdown]
# # 5. BUILD MODEL
#
# - Transfer learning is the core idea here. Instead of training a huge neural network from scratch (which needs tons of data and compute).
# - I am reusing one that's already been trained on a massive dataset (ImageNet has millions of images across 1,000 categories).
# - `MobileNet` has already learned to detect edges, textures, shapes, and complex patterns — so why redo all that work? hahaha
#
# ### The custom classifier on top (64 neurons → 5 classes)
# - This is the `new brain`. It takes MobileNet's pattern summary and learns to map it to your specific task: classifying 5 rice varieties.
# - The Dense layer with `64 neurons` gives it some capacity to learn combinations of features, and the final 5-neuron layer outputs a probability for each rice type.
# - `MobileNet features (1,280 values)` — MobileNet looks at my rice image and distills it into a vector of 1,280 numbers.
#     - Each number encodes something it detected — maybe "long grain shape" or "rough texture" or "brown color." These are powerful but generic; MobileNet doesn't know anything about rice varieties.
# - `Dense layer (64 neurons)` — Each of these 64 neurons receives all 1,280 feature values, multiplied by learned weights. This is where the model learns to combine features meaningfully: "long + thin + smooth = probably Basmati" vs "short + round + starchy = probably Arborio."
#     - The ReLU activation then zeroes out any negative values, keeping only the useful combinations.
# - Output layer (5 neurons) — Each neuron here corresponds to one rice variety. It takes the 64 combined features and produces a raw score.
#     - The softmax function then converts those 5 raw scores into probabilities that add up to 1.0. The highest probability is the model's prediction.

# %%
base_model = MobileNet(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3),
)
# Unfreeze the last 20 layers of MobileNet for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

transfer_model = Sequential([
    base_model,
    Flatten(),
    Dense(64, activation="relu"),
    Dense(NUM_CLASSES, activation="softmax"),
])

transfer_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=["acc"],
)

transfer_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenet_1.00_224 (Functional) │ (None, 7, 7, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     3,211,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,440,517 (24.57 MB)
#  Trainable params: 5,074,309 (19.36 MB)
#  Non-trainable params: 1,366,208 (5.21 MB)

# %% [markdown]
# # 6. TRAIN

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1),
    ModelCheckpoint("best_rice_model.keras", monitor="val_acc", save_best_only=True, verbose=1),
]

history = transfer_model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - acc: 0.8488 - loss: 0.5212
# Epoch 1: val_acc improved from None to 0.98294, saving model to best_rice_model.keras
#
# Epoch 1: finished saving model to best_rice_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 176ms/step - acc: 0.9308 - loss: 0.2254 - val_acc: 0.9829 - val_loss: 0.0536 - learning_rate: 1.0000e-04
# Epoch 2/30
#   1/175 ━━━━━━━━━━━━━━━━━━━━ 31s 183ms/step - acc: 1.0000 - loss: 0.0109
# Epoch 2: val_acc improved from 0.98294 to 0.98507, saving model to best_rice_model.keras
#
# Epoch 2: finished saving model to best_rice_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 1.0000 - loss: 0.0109 - val_acc: 0.9851 - val_loss: 0.0472 - learning_rate: 1.0000e-04
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - acc: 0.9743 - loss: 0.0860
# Epoch 3: val_acc improved from 0.98507 to 0.99147, saving model to best_rice_model.keras
#
# Epoch 3: finished saving model to best_rice_model.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 31s 175ms/step - acc: 0.9775 - loss: 0.0743 - val_acc: 0.9915 - val_loss: 0.0266 - learning_rate: 1.0000e-04
# Epoch 4/30
#   1/175 ━━━━━━━━━━━━━━━━━━━━ 31s 179ms/step - acc: 1.0000 - loss: 0.0028
# Epoch 4: val_acc did not improve from 0.99147
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 1.0000 - loss: 0.0028 - val_acc: 0.9915 - val_loss: 0.0268 - learning_rate: 1.0000e-04
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - acc: 0.9810 - loss: 0.0647
# Epoch 5: val_acc did not improve from 0.99147
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 182ms/step - acc: 0.9798 - loss: 0.0638 - val_acc: 0.9883 - val_loss: 0.0519 - learning_rate: 1.0000e-04
# Epoch 6/30
#   1/175 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - acc: 1.0000 - loss: 0.0130
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 6: val_acc did not improve from 0.99147
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 1.0000 - loss: 0.0130 - val_acc: 0.9851 - val_loss: 0.0557 - learning_rate: 1.0000e-04
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - acc: 0.9860 - loss: 0.0443
# Epoch 7: val_acc did not improve from 0.99147
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 31s 179ms/step - acc: 0.9882 - loss: 0.0393 - val_acc: 0.9861 - val_loss: 0.0671 - learning_rate: 5.0000e-05
# Epoch 8/30
#   1/175 ━━━━━━━━━━━━━━━━━━━━ 25s 145ms/step - acc: 0.9375 - loss: 0.0837
# Epoch 8: val_acc did not improve from 0.99147
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9375 - loss: 0.0837 - val_acc: 0.9872 - val_loss: 0.0614 - learning_rate: 5.0000e-05

# %% [markdown]
# # 7. EVALUATE

# %%
y_pred = transfer_model.predict(X_test, batch_size=BATCH_SIZE)
y_pred_labels = np.argmax(y_pred, axis=1)

print(f"\nTest Accuracy: {accuracy_score(y_test, y_pred_labels):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_labels, target_names=class_names))
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step
#
# Test Accuracy: 0.9925
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Arborio       0.98      1.00      0.99       187
#      Basmati       0.99      0.99      0.99       188
#       Ipsala       0.99      1.00      0.99       187
#      Jasmine       0.99      0.98      0.99       187
#    Karacadag       1.00      0.99      0.99       188
#
#     accuracy                           0.99       937
#    macro avg       0.99      0.99      0.99       937
# weighted avg       0.99      0.99      0.99       937

# %% [markdown]
# **Based on the above:**
# - The model is classifying rice varieties nearly perfectly — `99.7% accuracy`.
# - Out of `375 test images`, it only misclassified about 1.
# - Every variety has precision, recall, and F1 scores at or near 1.00.
#
# `In short:` the model works really well on this test set. One small caveat — with only 600 images per class, it's worth testing on fully new data to confirm it generalizes beyond this dataset.

# %% [markdown]
# # 8. VISUALIZE RESULTS
# ### Accuracy & Loss curves

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))
fig.suptitle("Training History")

ax1.set_title("Accuracy")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Accuracy")
ax1.plot(history.history["acc"], marker="o", label="Train")
ax1.plot(history.history["val_acc"], marker="o", label="Val")
ax1.legend()
ax1.grid(True)

ax2.set_title("Loss")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Loss")
ax2.plot(history.history["loss"], marker="o", label="Train")
ax2.plot(history.history["val_loss"], marker="o", label="Val")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig("training_history.png", dpi=100)
plt.show()

# %% [markdown]
# The training accuracy swings between ~0.84 and 1.00, and the loss is still erratic.
#
# This suggests the batch size may be too small relative to the data variance, causing noisy gradient updates.
#
#
# Worth trying next:
# - Increase batch size to 64 or 128
# - Increase samples per class further (e.g., 3000+)
# - Freeze MobileNet entirely first for a few epochs, then unfreeze for fine-tuning (two-phase training)

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm / cm.sum(axis=1, keepdims=True),
    fmt=".2%",
    annot=True,
    cmap="vlag",
    xticklabels=class_names,
    yticklabels=class_names,
)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=100)
plt.show()

print("\nModel saved to: best_rice_model.keras")
# Out:
# Model saved to: best_rice_model.keras

# %% [markdown]
# ## Take Away
#
# Despite the unstable training curves, the model actually classifies very well on the test set:
#
# - Arborio & Ipsala: perfect 100%
# - Basmati & Karacadag: ~99%
# - Jasmine: weakest at ~98%, occasionally confused with Arborio, Basmati, and Ipsala
#
# `The main takeaway:` Jasmine is the hardest variety to distinguish — it gets misclassified as other types more than any other class. Stabilizing the training (as discussed) would likely clean up these small errors.
